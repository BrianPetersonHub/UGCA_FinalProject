# %% [markdown]
# Using NewsAPI.org and its key to get news for past 1 month for 10 public companies

# %%
#using key : <HIDDEN : Ask Abhilasha personally for the key>

# %%
import requests,json

api_url = "https://newsapi.org/v2/everything?q=google&from=2018-10-27&sortBy=publishedAt&apiKey=<EnterKey>"
headers = {"Content-type": "application/json",
            "Accept": "text/plain"}
r = requests.get(api_url,headers)
response_google = r.json()

print(response_google)
# Out:
# {'status': 'ok', 'totalResults': 91408, 'articles': [{'source': {'id': None, 'name': 'Techtarget.com'}, 'author': None, 'title': "What's driving the next-generation mobile user experience", 'description': 'Several factors are changing the way organizations deliver the mobile user experience to employees. Learn how network advancements, voice technology and more make for next-gen mobile.', 'url': 'https://searchmobilecomputing.techtarget.com/opinion/Whats-driving-the-next-generation-mobile-user-experience', 'urlToImage': 'https://cdn.ttgtmedia.com/visuals/searchSalesForce/sales_management_software/salesforce_article_033.jpg', 'publishedAt': '2018-11-27T15:28:22Z', 'content': "Several recent technology advancements have contributed to the next-generation mobile user experience that many organizations now aim to deliver to their employees. Most organizations' mobile efforts have evolved beyond the basics of a mobile-friendly website… [+4945 chars]"}, {'source': {'id': None, 'name': 'Tec
# ...

# %%
# response = []
# tmp = dict()
# tmp['status'] = res['status']
# tmp['totalResults'] = res['totalResults']

# %%
import requests,json

api_url = "https://newsapi.org/v2/everything?q='apple'&from=2018-10-27&sortBy=popularity&apiKey=<EnterKey>"
headers = {"Content-type": "application/json",
            "Accept": "text/plain"}
r = requests.get(api_url,headers)
response_apple = r.json()

print(response_apple)
# Out:
# {'status': 'ok', 'totalResults': 81480, 'articles': [{'source': {'id': None, 'name': 'Lifehacker.com'}, 'author': 'Nick Douglas', 'title': 'Upgrade Your Weed Habit With /R/StonerEngineering', 'description': 'Screenshot: Relativity Media The use of psychoactive cannabis stretches back to ancient Mesopotamia. Tool use stretches back to our pre-human ancestors. These mighty forces converge on /r/StonerEngineering, a subreddit for weed hacks. Some hacks are high-tech…', 'url': 'https://lifehacker.com/upgrade-your-weed-habit-with-r-stonerengineering-1830189849', 'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/s--Unh9qLjK--/c_fill,fl_progressive,g_center,h_900,q_80,w_1600/vkhjki4tzll1ishnpafe.png', 'publishedAt': '2018-11-05T15:00:00Z', 'content': 'The use of psychoactive cannabis stretches back to ancient Mesopotamia. Tool use stretches back to our pre-human ancestors. These mighty forces converge on /r/StonerEngineering, a subreddit for weed hacks. Some hacks are high-te
# ...

# %%
import requests,json

api_url = "https://newsapi.org/v2/everything?q='microsoft'&from=2018-10-27&sortBy=popularity&apiKey=<EnterKey>"
headers = {"Content-type": "application/json",
            "Accept": "text/plain"}
r = requests.get(api_url,headers)
response_ms = r.json()

print(response_ms)
# Out:
# {'status': 'ok', 'totalResults': 34855, 'articles': [{'source': {'id': None, 'name': 'Theinventory.com'}, 'author': 'Shep McAllister on Kinja Deals, shared by Shep McAllister to Lifehacker', 'title': "Sunday's Best Deals...Are Just a Whole Bunch of Early Black Friday Deals", 'description': '&lt;Psssst&gt; Black Friday is starting now. You can already save on a ton of PS4 stuff, Anova sous-vide circulators, an Xbox One S bundle, Microsoft Surfaces, and a lot more. Read more...', 'url': 'https://kinjadeals.theinventory.com/sundays-best-deals-are-just-a-whole-bunch-of-early-bl-1830519050', 'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/s--zf0l0kKv--/c_fill,fl_progressive,g_center,h_900,q_80,w_1600/hobzxhk1ybtuwo3nyf4g.jpg', 'publishedAt': '2018-11-18T15:35:00Z', 'content': '&lt;Psssst&gt; Black Friday is starting now. You can already save on a ton of PS4 stuff, Anova sous-vide circulators, an Xbox One S bundle, Microsoft Surfaces, and a lot more. Bookmark Kinja Deals a
# ...
